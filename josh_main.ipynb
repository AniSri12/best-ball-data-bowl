# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import Data

# %% [markdown]
# #### 2022 Fast Drafts Regular Season

# %%
df1 = pd.read_csv('data/2022/regular_season/fast/part_00.csv', delimiter=',')
df2 = pd.read_csv('data/2022/regular_season/fast/part_01.csv', delimiter=',')
df3 = pd.read_csv('data/2022/regular_season/fast/part_02.csv', delimiter=',')
df4 = pd.read_csv('data/2022/regular_season/fast/part_03.csv', delimiter=',')
df5 = pd.read_csv('data/2022/regular_season/fast/part_04.csv', delimiter=',')
df6 = pd.read_csv('data/2022/regular_season/fast/part_05.csv', delimiter=',')
df7 = pd.read_csv('data/2022/regular_season/fast/part_06.csv', delimiter=',')
df8 = pd.read_csv('data/2022/regular_season/fast/part_07.csv', delimiter=',')
df9 = pd.read_csv('data/2022/regular_season/fast/part_08.csv', delimiter=',')
df10 = pd.read_csv('data/2022/regular_season/fast/part_09.csv', delimiter=',')
df11 = pd.read_csv('data/2022/regular_season/fast/part_10.csv', delimiter=',')
df12 = pd.read_csv('data/2022/regular_season/fast/part_11.csv', delimiter=',')
df13 = pd.read_csv('data/2022/regular_season/fast/part_12.csv', delimiter=',')
df14 = pd.read_csv('data/2022/regular_season/fast/part_13.csv', delimiter=',')
df15 = pd.read_csv('data/2022/regular_season/fast/part_14.csv', delimiter=',')
df16 = pd.read_csv('data/2022/regular_season/fast/part_15.csv', delimiter=',')
df17 = pd.read_csv('data/2022/regular_season/fast/part_16.csv', delimiter=',')
df18 = pd.read_csv('data/2022/regular_season/fast/part_17.csv', delimiter=',')
df19 = pd.read_csv('data/2022/regular_season/fast/part_18.csv', delimiter=',')
df20 = pd.read_csv('data/2022/regular_season/fast/part_19.csv', delimiter=',')
df21 = pd.read_csv('data/2022/regular_season/fast/part_20.csv', delimiter=',')
df22 = pd.read_csv('data/2022/regular_season/fast/part_21.csv', delimiter=',')
df23 = pd.read_csv('data/2022/regular_season/fast/part_22.csv', delimiter=',')
df24 = pd.read_csv('data/2022/regular_season/fast/part_23.csv', delimiter=',')
df25 = pd.read_csv('data/2022/regular_season/fast/part_24.csv', delimiter=',')
df26 = pd.read_csv('data/2022/regular_season/fast/part_25.csv', delimiter=',')
df27 = pd.read_csv('data/2022/regular_season/fast/part_26.csv', delimiter=',')

# %%
df_2022_fast = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,
                         df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27],
                        ignore_index=True)
df_2022_fast
# Out:
#                                      draft_id                  draft_time  \
# 0        d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 1        d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 2        d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 3        d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 4        d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# ...                                       ...                         ...
# 6091195  d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 6091196  d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 6091197  d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 6091198  d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
# 6091199  d4e1b2c6-26e0-48ec-a2e9-ca4d43f00ade  2022-08-27 05:38:33.558728
#
#          clock                        draft_entry_id  \
# ...

# %% [markdown]
# #### 2022 Mixed Drafts Regular Season

# %%
df1m = pd.read_csv('data/2022/regular_season/mixed/part_00.csv', delimiter=',')
df2m = pd.read_csv('data/2022/regular_season/mixed/part_01.csv', delimiter=',')
df3m = pd.read_csv('data/2022/regular_season/mixed/part_02.csv', delimiter=',')
df4m = pd.read_csv('data/2022/regular_season/mixed/part_03.csv', delimiter=',')
df5m = pd.read_csv('data/2022/regular_season/mixed/part_04.csv', delimiter=',')
df6m = pd.read_csv('data/2022/regular_season/mixed/part_05.csv', delimiter=',')
df7m = pd.read_csv('data/2022/regular_season/mixed/part_06.csv', delimiter=',')
df8m = pd.read_csv('data/2022/regular_season/mixed/part_07.csv', delimiter=',')
df9m = pd.read_csv('data/2022/regular_season/mixed/part_08.csv', delimiter=',')

# %%
df_2022_mixed = pd.concat([df1m,df2m,df3m,df4m,df5m,df6m,df7m,df8m,df9m],
                    ignore_index=True)
df_2022_mixed
# Out:
#                                      draft_id                  draft_time  \
# 0        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 1        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 2        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 3        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 4        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# ...                                       ...                         ...
# 2030395  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030396  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030397  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030398  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030399  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
#
#          clock                        draft_entry_id  \
# ...

# %% [markdown]
# #### 2022 Postseason

# %%
df_fin = pd.read_csv('data/2022/post_season/finals/part_00.csv', delimiter=',')
df_semi = pd.read_csv('data/2022/post_season/semifinals/part_00.csv', delimiter=',')
df_q1 = pd.read_csv('data/2022/post_season/quarterfinals/part_00.csv', delimiter=',')
df_q2 = pd.read_csv('data/2022/post_season/quarterfinals/part_01.csv', delimiter=',')
df_q3 = pd.read_csv('data/2022/post_season/quarterfinals/part_02.csv', delimiter=',')

# %%
df_2022_quarterfinals = pd.concat([df_q1, df_q2, df_q3], ignore_index=True)
df_2022_semifinals = df_semi.copy()
df_2022_finals = df_fin.copy()

# %%
df_2022_quarterfinals
# Out:
#                                     draft_id  draft_time  clock  \
# 0       ab92023d-7d04-4755-a90f-0aa0ffdb8114         NaN     30
# 1       ab92023d-7d04-4755-a90f-0aa0ffdb8114         NaN     30
# 2       ab92023d-7d04-4755-a90f-0aa0ffdb8114         NaN     30
# 3       ab92023d-7d04-4755-a90f-0aa0ffdb8114         NaN     30
# 4       ab92023d-7d04-4755-a90f-0aa0ffdb8114         NaN     30
# ...                                      ...         ...    ...
# 451195  fff415c2-3a48-40cc-b31a-36bbbe6de992         NaN     30
# 451196  fff415c2-3a48-40cc-b31a-36bbbe6de992         NaN     30
# 451197  fff415c2-3a48-40cc-b31a-36bbbe6de992         NaN     30
# 451198  fff415c2-3a48-40cc-b31a-36bbbe6de992         NaN     30
# 451199  fff415c2-3a48-40cc-b31a-36bbbe6de992         NaN     30
#
#                               draft_entry_id  \
# 0       fa5a62f7-d079-4222-92f9-53904cc23a88
# 1       8f2f60e7-bf77-4e9f-85da-f41fda04b3d5
# 2       8f2f60e7-bf77-4e9f-85da-f41fda04b3d5
# ...

# %% [markdown]
# #### 2021 Regular Season

# %%
df211 = pd.read_csv('data/2021/regular_season/part_00.csv', delimiter=',')
df212 = pd.read_csv('data/2021/regular_season/part_01.csv', delimiter=',')
df213 = pd.read_csv('data/2021/regular_season/part_02.csv', delimiter=',')
df214 = pd.read_csv('data/2021/regular_season/part_03.csv', delimiter=',')
df215 = pd.read_csv('data/2021/regular_season/part_04.csv', delimiter=',')
df216 = pd.read_csv('data/2021/regular_season/part_05.csv', delimiter=',')

# %%
df_2021_rs = pd.concat([df1m,df2m,df3m,df4m,df5m,df6m,df7m,df8m,df9m],
             ignore_index=True)
df_2021_rs
# Out:
#                                      draft_id                  draft_time  \
# 0        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 1        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 2        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 3        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# 4        00012b23-0f2c-4727-b1ab-05b4a0120a76  2022-08-19 23:49:44.511157
# ...                                       ...                         ...
# 2030395  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030396  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030397  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030398  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
# 2030399  3f80c167-dd24-44f6-8f6c-40cc85d5aa7a  2022-08-22 16:16:43.340393
#
#          clock                        draft_entry_id  \
# ...

# %% [markdown]
# #### 2021 Postseason

# %%
df_2021_quarterfinals = pd.read_csv('data/2021/post_season/quarterfinals.csv', delimiter=',')
df_2021_semifinals = pd.read_csv('data/2021/post_season/semifinals.csv', delimiter=',')
df_2021_finals = pd.read_csv('data/2021/post_season/finals.csv', delimiter=',')

# %% [markdown]
# ## Now, all of our data is loaded into the following dataframes:
# #### df_2022_fast (fast draft 2022 regular season data)
# #### df_2022_mixed (mixed draft 2022 regulars season data)
# #### df_2022_quarterfinals (2022 quarterfinals data)
# #### df_2022_semifinals (2022 semifinals data)
# #### df_2022_finals (2022 finals data)
# #### df_2021_rs (2021 regular season data)
# #### df_2021_quarterfinals (2021 quarterfinals data)
# #### df_2021_semifinals (2021 semifinals data)
# #### df_2021_finals (2021 finals data)

# %% [markdown]
# ### Let's group the data by team using draft_entry_id to begin exploring team structures. Let's start with regular season data

# %%
df_2022_rs_teams = df_2022_fast.groupby(['draft_entry_id','team_pick_number'])
df_2022_rs_teams.first()
# Out:
#                                                                                    draft_id  \
# draft_entry_id                       team_pick_number
# 0000259d-9aaa-41fc-863f-50f0bd541019 1                 d470904d-7459-4712-a221-7fee5375d8ae
#                                      2                 d470904d-7459-4712-a221-7fee5375d8ae
#                                      3                 d470904d-7459-4712-a221-7fee5375d8ae
#                                      4                 d470904d-7459-4712-a221-7fee5375d8ae
#                                      5                 d470904d-7459-4712-a221-7fee5375d8ae
# ...                                                                                     ...
# ffff60b0-41ba-4f35-a064-55a2c1660412 14                a7c92bf3-7151-4726-a72b-a1e11fa309cd
#                                      15                a7c92bf3-7151-4726-a72b-a1e11fa309cd
#                                      16                a7c92bf3-7151-4726-a72b-a1e11fa309cd
# ...
